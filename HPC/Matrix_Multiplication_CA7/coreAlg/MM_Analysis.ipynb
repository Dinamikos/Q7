# %% [markdown]
# # Matrix Multiplication Analysis CA7
#
# ---
#
# **Team**
#
# 1. Juan Manuel Balanzar Vega
# 2. Isabel Camara Montalvo
# 3. Victor Rodrigo Uribe Hernandez
# 4. Osiris Odett Camara Salinas
# 5. Mayte Alejandra Chi Poot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
run_time_col350 = [0.147, 0.153, 0.153, 0.155, 0.154, 0.157, 0.160, 0.154]

# %%
speed_up_col350 = [0.0272, 0.0261, 0.0261, 0.0258, 0.0259, 0.0254, 0.025, 0.0259]

# %%
run_time_col100 = [0.005, 0.007, 0.005, 0.004, 0.004, 0.004, 0.005, 0.004]

# %%
speed_up_col100 = [0.25, 0.16, 0.25, 0.33, 0.33, 0.33, 0.25, 0.33]

# %%
p = 9
fig= plt.figure(figsize=(10,5))
x= np.arange(1,p,1)
plt.plot(x, run_time_col350, 'g.-', label='Running time')

plt.xlabel('No. threads')
plt.ylabel('Running time')
plt.grid()
plt.title("Matrix Multiplication Column Decomposition")
plt.legend(loc='upper left')
plt.show()

# %%
fig= plt.figure(figsize=(10,5))
x= np.arange(1,p,1)
plt.plot(x, speed_up_col350, 'b.-', label='Speedup')

plt.xlabel('No. threads')
plt.ylabel('Speedup')
plt.grid()
plt.title("Matrix Multiplication Column Decomposition")
plt.legend(loc='upper left')
plt.show()
